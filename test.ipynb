# %%
# !pip install sentence-transformers pillow chromadb

# %%
# !pip install torch torchvision torchaudio opencv-python scikit-image

# %%
from room_recognition import add_room_image, predict_room

# Step 1: Add reference room images
add_room_image("study room", "images/study_room.jpg")
add_room_image("bedroom", "images/bed_room.jpg")
add_room_image("living room", "images/living_room.jpg")

# Step 2: Test predictions
predict_room("test_images/test1.jpg")
predict_room("test_images/test2.jpg")
predict_room("test_images/test3.jpg")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# ✅ Added 'study room' from images/study_room.jpg
# ✅ Added 'bedroom' from images/bed_room.jpg
# ✅ Added 'living room' from images/living_room.jpg
#
# 🔍 Similar Rooms for: test_images/test1.jpg
# 1. bedroom → similarity: 0.868
# 2. living room → similarity: 0.770
# 3. study room → similarity: 0.637
#
# 📍 Predicted room: bedroom
#
# 🔍 Similar Rooms for: test_images/test2.jpg
# 1. living room → similarity: 0.892
# 2. bedroom → similarity: 0.838
# 3. study room → similarity: 0.784
#
# 📍 Predicted room: living room
#
# 🔍 Similar Rooms for: test_images/test3.jpg
# 1. study room → similarity: 0.757
# 2. bedroom → similarity: 0.738
# 3. living room → similarity: 0.723
#
# ...
